# %%
import seaborn as sns
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#dist plot- helps unvariate

# %%
sns.distplot(tips['total_bill'],kde=False,bins=30)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#joint plot-for bivariate and combines two distplots

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')

# %%
#pairplot- relationship for entire dataset nuerical columns

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %%
#rugplot

# %%
sns.rugplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'],kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#kdeplots=kernel density estimation plot: sum f all the normal distributions around a rug plot

# %%
#categorical plots

# %%
#barplot: allows aggregrating categorical data by aggregrate unction like groupby

# %%
sns.barplot(x='sex',y='total_bill',data=tips, estimator=np.std)

# %%
import numpy as np

# %%
#count plot: estimator is counting number of occurrnces

# %%
sns.countplot(x='sex',data=tips)

# %%
#boxplots and violin plots: shows distribution of categorical data

# %%
sns.boxplot(x='day',y='total_bill',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex',split=True)

# %%
#violin plots plots the kde

# %%
#stripplot:scatterplot for categorical

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True,hue='sex',split=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:2586: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
#swarm plot: strip plus violin , points are adjusted so that it doesn overlap, they dont scale and is computationally expensve for swarm plots

# %%
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')
sns.violinplot(x='day',y='total_bill',data=tips)

# %%
#factor plot:

# %%
sns.factorplot(x='day',y='total_bill',data=tips,kind='violin')

# %%
#matrixplots:heat maps
#data should be in matrix form

# %%
flights=sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tc=tips.corr()

# %%
sns.heatmap(tc,annot=True,cmap='coolwarm')

# %%
fp=flights.pivot_table(index='month',columns='year',values='passengers')

# %%
sns.heatmap(fp)

# %%
#clustermap: uses hierarchial clustering on heat map

# %%
sns.clustermap(fp,cmap='coolwarm',standard_scale=1)

# %%
#Grids:autmate subplots based on data features

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# %%
g=sns.PairGrid(iris)
g.map(plt.scatter)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ...

# %%
import matplotlib.pyplot as plt

# %%
#facetgrid

# %%
facet=sns.FacetGrid(tips,col='time',row='smoker')
facet.map(sns.distplot,'total_bill')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#Regression plots

# %%
#lmplot:linear model representation

# %%
sns.lmplot('total_bill','tip',tips,hue='sex')
